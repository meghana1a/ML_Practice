# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana1a/ML_Practice/blob/main/decision_tree_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Dataset

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, accuracy_score, precision_score, recall_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Feature Selection

# %%
selected_cols=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
x=data[selected_cols]
y=data.Species

# %%
feature_names = x
labels = y.unique()
feature_names
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Spliting the dataset

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# ## Decision Tree Classifier

# %%
clf = DecisionTreeClassifier(max_depth =4, random_state = 42)
clf.fit(X_train, y_train)
pred_decision_tree = clf.predict(X_test)

# %% [markdown]
# ### Plot the Decision Tree using tree plot

# %%
from sklearn import tree
import matplotlib.pyplot as plt

plt.figure(figsize=(30,10))

a = tree.plot_tree(clf,

                   class_names=labels,

                   rounded = True,

                   filled = True,

                   fontsize=14)

plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
cnf_matrix = confusion_matrix(y_test, pred_decision_tree )
print(cnf_matrix)
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix = cnf_matrix)
cm_display.plot()
plt.show()

# %%
print("Precision Score : ",precision_score(y_test, pred_decision_tree , average='micro'))
print("Recall Score : ",recall_score(y_test, pred_decision_tree , average='micro'))
print("Accuracy Score : ",accuracy_score(y_test, pred_decision_tree ))
# Out:
# Precision Score :  0.9736842105263158
# Recall Score :  0.9736842105263158
# Accuracy Score :  0.9736842105263158

# %% [markdown]
# ## Prediction of classes for x_test

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %% [markdown]
# ### Predictions for X_test using the model

# %%
predictions = clf.predict(X_test)
print(X_test,"\n",predictions)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114            5.8           2.8            5.1           2.4
# 62             6.0           2.2            4.0           1.0
# 33             5.5           4.2            1.4           0.2
# 107            7.3           2.9            6.3           1.8
# 7              5.0           3.4            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 40             5.0           3.5            1.3           0.3
# 86             6.7           3.1            4.7           1.5
# 76             6.8           2.8            4.8           1.4
# 71             6.1           2.8            4.0           1.3
# 134            6.1           2.6            5.6           1.4
# 51             6.4           3.2            4.5           1.5
# 73             6.1           2.8            4.7           1.2
# 54             6.5           2.8            4.6           1.5
# ...

# %%
feature_names
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]
